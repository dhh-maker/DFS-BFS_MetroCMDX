# %% [markdown]
# # 1. DFS Y BFS EN ACCIÓN CON EL METRO DE LA CIUDAD DE MÉXICO

# %%
class Problem:
    def __init__(self, initial, goal):
        self.initial = initial # Estado inicial
        self.goal = goal # Meta

    def actions(self, state):
        raise NotImplementedError

    # Función de transición
    def result(self, state, action):
        raise NotImplementedError

    # Función de desempeño
    def is_goal(self, state):
        return self.goal == state

    def action_cost(self, state1, action, state2):
        return 1

    def h(self, state):
        return 0

# %%
class GraphProblem(Problem):
    def __init__(self, initial, goal, graph):
        super().__init__(initial, goal)
        self.graph = graph

    def actions(self, state):
        lista = []
        for key in self.graph[state].keys():
            lista.append(key)
        return lista

    # Función de transición
    def result(self, state, action):
        return action

    def action_cost(self, state1, action, state2):
        return self.graph[state1][state2]

# %%
metro_cdmx = {
    # --- LÍNEA 1 (Rosa) ---
    'Observatorio': {'Tacubaya': 1.262},
    'Tacubaya': {'Observatorio': 1.262, 'Juanacatlán': 1.158, 'Patriotismo': 1.133, 'Constituyentes': 1.005, 'San Pedro de los Pinos': 1.084},
    'Juanacatlán': {'Tacubaya': 1.158, 'Chapultepec': 0.973},
    'Chapultepec': {'Juanacatlán': 0.973, 'Sevilla': 0.501},
    'Sevilla': {'Chapultepec': 0.501, 'Insurgentes': 0.645},
    'Insurgentes': {'Sevilla': 0.645, 'Cuauhtémoc': 0.793},
    'Cuauhtémoc': {'Insurgentes': 0.793, 'Balderas': 0.409},
    'Balderas': {'Cuauhtémoc': 0.409, 'Salto del Agua': 0.458, 'Juárez': 0.659, 'Niños Héroes': 0.665},
    'Salto del Agua': {'Balderas': 0.458, 'Isabel la Católica': 0.445, 'San Juan de Letrán': 0.292, 'Doctores': 0.564},
    'Isabel la Católica': {'Salto del Agua': 0.445, 'Pino Suárez': 0.382},
    'Pino Suárez': {'Isabel la Católica': 0.382, 'Merced': 0.745, 'Zócalo': 0.745, 'San Antonio Abad': 0.817},
    'Merced': {'Pino Suárez': 0.745, 'Candelaria': 0.698},
    'Candelaria': {'Merced': 0.698, 'San Lázaro': 0.866, 'Morelos': 1.062, 'Fray Servando': 0.633},
    'San Lázaro': {'Candelaria': 0.866, 'Moctezuma': 0.478, 'Morelos': 1.296, 'Flores Magón': 0.907},
    'Moctezuma': {'San Lázaro': 0.478, 'Balbuena': 0.703},
    'Balbuena': {'Moctezuma': 0.703, 'Boulevard Puerto Aéreo': 0.595},
    'Boulevard Puerto Aéreo': {'Balbuena': 0.595, 'Gómez Farías': 0.611},
    'Gómez Farías': {'Boulevard Puerto Aéreo': 0.611, 'Zaragoza': 0.762},
    'Zaragoza': {'Gómez Farías': 0.762, 'Pantitlán': 1.320},
    'Pantitlán': {'Zaragoza': 1.320, 'Hangares': 1.644, 'Puebla': 1.380, 'Agrícola Oriental': 1.409},

    # --- LÍNEA 2 (Azul) ---
    'Cuatro Caminos': {'Panteones': 1.639},
    'Panteones': {'Cuatro Caminos': 1.639, 'Tacuba': 1.416},
    'Tacuba': {'Panteones': 1.416, 'Cuitláhuac': 0.637, 'Refinería': 1.295, 'San Joaquín': 1.433},
    'Cuitláhuac': {'Tacuba': 0.637, 'Popotla': 0.620},
    'Popotla': {'Cuitláhuac': 0.620, 'Colegio Militar': 0.462},
    'Colegio Militar': {'Popotla': 0.462, 'Normal': 0.516},
    'Normal': {'Colegio Militar': 0.516, 'San Cosme': 0.657},
    'San Cosme': {'Normal': 0.657, 'Revolución': 0.537},
    'Revolución': {'San Cosme': 0.537, 'Hidalgo': 0.587},
    'Hidalgo': {'Revolución': 0.587, 'Bellas Artes': 0.447, 'Guerrero': 0.702, 'Juárez': 0.251},
    'Bellas Artes': {'Hidalgo': 0.447, 'Allende': 0.387, 'Garibaldi': 0.634, 'San Juan de Letrán': 0.456},
    'Allende': {'Bellas Artes': 0.387, 'Zócalo': 0.602},
    'Zócalo': {'Allende': 0.602, 'Pino Suárez': 0.745},
    'San Antonio Abad': {'Pino Suárez': 0.817, 'Chabacano': 0.642},
    'Chabacano': {'San Antonio Abad': 0.642, 'Viaducto': 0.774, 'Obrera': 1.143, 'La Viga': 0.843, 'Lázaro Cárdenas': 1.000, 'Jamaica': 1.031},
    'Viaducto': {'Chabacano': 0.774, 'Xola': 0.490},
    'Xola': {'Viaducto': 0.490, 'Villa de Cortés': 0.698},
    'Villa de Cortés': {'Xola': 0.698, 'Nativitas': 0.750},
    'Nativitas': {'Villa de Cortés': 0.750, 'Portales': 0.924},
    'Portales': {'Nativitas': 0.924, 'Ermita': 0.748},
    'Ermita': {'Portales': 0.748, 'General Anaya': 0.838, 'Eje Central': 0.895, 'Mexicaltzingo': 1.805},
    'General Anaya': {'Ermita': 0.838, 'Tasqueña': 1.330},
    'Tasqueña': {'General Anaya': 1.330},

    # --- LÍNEA 3 (Verde) ---
    'Indios Verdes': {'Deportivo 18 de Marzo': 1.166},
    'Deportivo 18 de Marzo': {'Indios Verdes': 1.166, 'Potrero': 0.966, 'Lindavista': 1.075, 'La Villa Basílica': 0.704},
    'Potrero': {'Deportivo 18 de Marzo': 0.966, 'La Raza': 1.106},
    'La Raza': {'Potrero': 1.106, 'Tlatelolco': 1.445, 'Autobuses del Norte': 0.975, 'Misterios': 0.892},
    'Tlatelolco': {'La Raza': 1.445, 'Guerrero': 1.042},
    'Guerrero': {'Tlatelolco': 1.042, 'Hidalgo': 0.702, 'Buenavista': 0.521, 'Garibaldi': 0.752},
    'Juárez': {'Hidalgo': 0.251, 'Balderas': 0.659},
    'Niños Héroes': {'Balderas': 0.665, 'Hospital General': 0.559},
    'Hospital General': {'Niños Héroes': 0.559, 'Centro Médico': 0.653},
    'Centro Médico': {'Hospital General': 0.653, 'Etiopía': 1.119, 'Chilpancingo': 1.031, 'Lázaro Cárdenas': 1.059},
    'Etiopía': {'Centro Médico': 1.119, 'Eugenia': 0.950},
    'Eugenia': {'Etiopía': 0.950, 'División del Norte': 0.715},
    'División del Norte': {'Eugenia': 0.715, 'Zapata': 0.794},
    'Zapata': {'División del Norte': 0.794, 'Coyoacán': 1.153, 'Hospital 20 de Noviembre': 0.450, 'Parque de los Venados': 1.280},
    'Coyoacán': {'Zapata': 1.153, 'Viveros': 0.908},
    'Viveros': {'Coyoacán': 0.908, 'Miguel Ángel de Quevedo': 0.885},
    'Miguel Ángel de Quevedo': {'Viveros': 0.885, 'Copilco': 1.295},
    'Copilco': {'Miguel Ángel de Quevedo': 1.295, 'Universidad': 1.306},
    'Universidad': {'Copilco': 1.306},

    # --- LÍNEA 4 (Cian) ---
    'Martín Carrera': {'Talismán': 1.129, 'La Villa Basílica': 1.141},
    'Talismán': {'Martín Carrera': 1.129, 'Bondojito': 0.989},
    'Bondojito': {'Talismán': 0.989, 'Consulado': 0.645},
    'Consulado': {'Bondojito': 0.645, 'Canal del Norte': 0.884, 'Valle Gómez': 0.679, 'Eduardo Molina': 0.815},
    'Canal del Norte': {'Consulado': 0.884, 'Morelos': 0.910},
    'Morelos': {'Canal del Norte': 0.910, 'Candelaria': 1.062, 'Tepito': 0.498, 'San Lázaro': 1.296},
    'Fray Servando': {'Candelaria': 0.633, 'Jamaica': 1.043},
    'Jamaica': {'Fray Servando': 1.043, 'Santa Anita': 0.758, 'Chabacano': 1.031, 'Mixiuhca': 0.942},
    'Santa Anita': {'Jamaica': 0.758, 'La Viga': 0.803, 'Coyuya': 0.968},

    # --- LÍNEA 5 (Amarilla) ---
    'Politécnico': {'Instituto del Petróleo': 1.188},
    'Instituto del Petróleo': {'Politécnico': 1.188, 'Autobuses del Norte': 1.067, 'Vallejo': 0.755, 'Lindavista': 1.258},
    'Autobuses del Norte': {'Instituto del Petróleo': 1.067, 'La Raza': 0.975},
    'Misterios': {'La Raza': 0.892, 'Valle Gómez': 0.969},
    'Valle Gómez': {'Misterios': 0.969, 'Consulado': 0.679},
    'Eduardo Molina': {'Consulado': 0.815, 'Aragón': 0.860},
    'Aragón': {'Eduardo Molina': 0.860, 'Oceanía': 1.219},
    'Oceanía': {'Aragón': 1.219, 'Terminal Aérea': 1.174, 'Romero Rubio': 0.866, 'Deportivo Oceanía': 0.863},
    'Terminal Aérea': {'Oceanía': 1.174, 'Hangares': 1.153},
    'Hangares': {'Terminal Aérea': 1.153, 'Pantitlán': 1.644},

    # --- LÍNEA 6 (Roja) ---
    'El Rosario': {'Tezozómoc': 1.257, 'Aquiles Serdán': 1.615},
    'Tezozómoc': {'El Rosario': 1.257, 'Azcapotzalco': 0.973},
    'Azcapotzalco': {'Tezozómoc': 0.973, 'Ferrería': 1.173},
    'Ferrería': {'Azcapotzalco': 1.173, 'Norte 45': 1.072},
    'Norte 45': {'Ferrería': 1.072, 'Vallejo': 0.715},
    'Vallejo': {'Norte 45': 0.715, 'Instituto del Petróleo': 0.755},
    'Lindavista': {'Instituto del Petróleo': 1.258, 'Deportivo 18 de Marzo': 1.075},
    'La Villa Basílica': {'Deportivo 18 de Marzo': 0.704, 'Martín Carrera': 1.141},

    # --- LÍNEA 7 (Naranja) ---
    'Aquiles Serdán': {'El Rosario': 1.615, 'Camarones': 1.402},
    'Camarones': {'Aquiles Serdán': 1.402, 'Refinería': 0.952},
    'Refinería': {'Camarones': 0.952, 'Tacuba': 1.295},
    'San Joaquín': {'Tacuba': 1.433, 'Polanco': 1.163},
    'Polanco': {'San Joaquín': 1.163, 'Auditorio': 0.812},
    'Auditorio': {'Polanco': 0.812, 'Constituyentes': 1.430},
    'Constituyentes': {'Auditorio': 1.430, 'Tacubaya': 1.005},
    'San Pedro de los Pinos': {'Tacubaya': 1.084, 'San Antonio': 0.606},
    'San Antonio': {'San Pedro de los Pinos': 0.606, 'Mixcoac': 0.788},
    'Mixcoac': {'San Antonio': 0.788, 'Barranca del Muerto': 1.476, 'Insurgentes Sur': 0.651},
    'Barranca del Muerto': {'Mixcoac': 1.476},

    # --- LÍNEA 8 (Verde Fuerte) ---
    'Garibaldi': {'Guerrero': 0.752, 'Bellas Artes': 0.634, 'Lagunilla': 0.474},
    'San Juan de Letrán': {'Bellas Artes': 0.456, 'Salto del Agua': 0.292},
    'Doctores': {'Salto del Agua': 0.564, 'Obrera': 0.761},
    'Obrera': {'Doctores': 0.761, 'Chabacano': 1.143},
    'La Viga': {'Chabacano': 0.843, 'Santa Anita': 0.803},
    'Coyuya': {'Santa Anita': 0.968, 'Iztacalco': 0.973},
    'Iztacalco': {'Coyuya': 0.973, 'Apatlaco': 0.906},
    'Apatlaco': {'Iztacalco': 0.906, 'Aculco': 0.534},
    'Aculco': {'Apatlaco': 0.534, 'Escuadrón 201': 0.789},
    'Escuadrón 201': {'Aculco': 0.789, 'Atlalilco': 1.738},
    'Atlalilco': {'Escuadrón 201': 1.738, 'Iztapalapa': 0.732, 'Mexicaltzingo': 1.922, 'Culhuacán': 1.530},
    'Iztapalapa': {'Atlalilco': 0.732, 'Cerro de la Estrella': 0.717},
    'Cerro de la Estrella': {'Iztapalapa': 0.717, 'UAM-I': 1.135},
    'UAM-I': {'Cerro de la Estrella': 1.135, 'Constitución de 1917': 1.137},
    'Constitución de 1917': {'UAM-I': 1.137},

    # --- LÍNEA 9 (Café) ---
    'Patriotismo': {'Tacubaya': 1.133, 'Chilpancingo': 0.965},
    'Chilpancingo': {'Patriotismo': 0.965, 'Centro Médico': 1.031},
    'Lázaro Cárdenas': {'Centro Médico': 1.059, 'Chabacano': 1.000},
    'Mixiuhca': {'Jamaica': 0.942, 'Velódromo': 1.062},
    'Velódromo': {'Mixiuhca': 1.062, 'Ciudad Deportiva': 1.110},
    'Ciudad Deportiva': {'Velódromo': 1.110, 'Puebla': 0.800},
    'Puebla': {'Ciudad Deportiva': 0.800, 'Pantitlán': 1.380},

    # --- LÍNEA A (Morada) ---
    'Agrícola Oriental': {'Pantitlán': 1.409, 'Canal de San Juan': 1.093},
    'Canal de San Juan': {'Agrícola Oriental': 1.093, 'Tepalcates': 1.456},
    'Tepalcates': {'Canal de San Juan': 1.456, 'Guelatao': 1.161},
    'Guelatao': {'Tepalcates': 1.161, 'Peñón Viejo': 1.542},
    'Peñón Viejo': {'Guelatao': 1.542, 'Acatitla': 1.378},
    'Acatitla': {'Peñón Viejo': 1.378, 'Santa Marta': 1.100},
    'Santa Marta': {'Acatitla': 1.100, 'Los Reyes': 1.373},
    'Los Reyes': {'Santa Marta': 1.373, 'La Paz': 1.956},
    'La Paz': {'Los Reyes': 1.956},

    # --- LÍNEA B (Verde/Gris) ---
    'Buenavista': {'Guerrero': 0.521},
    'Lagunilla': {'Garibaldi': 0.474, 'Tepito': 0.611},
    'Tepito': {'Lagunilla': 0.611, 'Morelos': 0.498},
    'Flores Magón': {'San Lázaro': 0.907, 'Romero Rubio': 0.812},
    'Romero Rubio': {'Flores Magón': 0.812, 'Oceanía': 0.866},
    'Deportivo Oceanía': {'Oceanía': 0.863, 'Bosque de Aragón': 1.048},
    'Bosque de Aragón': {'Deportivo Oceanía': 1.048, 'Villa de Aragón': 0.793},
    'Villa de Aragón': {'Bosque de Aragón': 0.793, 'Nezahualcóyotl': 1.335},
    'Nezahualcóyotl': {'Villa de Aragón': 1.335, 'Impulsora': 1.393},
    'Impulsora': {'Nezahualcóyotl': 1.393, 'Río de los Remedios': 0.824},
    'Río de los Remedios': {'Impulsora': 0.824, 'Múzquiz': 1.155},
    'Múzquiz': {'Río de los Remedios': 1.155, 'Ecatepec': 1.485},
    'Ecatepec': {'Múzquiz': 1.485, 'Olímpica': 0.596},
    'Olímpica': {'Ecatepec': 0.596, 'Plaza Aragón': 0.574},
    'Plaza Aragón': {'Olímpica': 0.574, 'Ciudad Azteca': 0.574},
    'Ciudad Azteca': {'Plaza Aragón': 0.574},

    # --- LÍNEA 12 (Dorada) ---
    'Insurgentes Sur': {'Mixcoac': 0.651, 'Hospital 20 de Noviembre': 0.725},
    'Hospital 20 de Noviembre': {'Insurgentes Sur': 0.725, 'Zapata': 0.450},
    'Parque de los Venados': {'Zapata': 1.280, 'Eje Central': 0.895},
    'Eje Central': {'Parque de los Venados': 0.895, 'Ermita': 0.895},
    'Mexicaltzingo': {'Ermita': 1.805, 'Atlalilco': 1.922},
    'Culhuacán': {'Atlalilco': 1.530, 'San Andrés Tomatlán': 0.980},
    'San Andrés Tomatlán': {'Culhuacán': 0.980, 'Lomas Estrella': 1.060},
    'Lomas Estrella': {'San Andrés Tomatlán': 1.060, 'Calle 11': 0.906},
    'Calle 11': {'Lomas Estrella': 0.906, 'Periférico Oriente': 0.985},
    'Periférico Oriente': {'Calle 11': 0.985, 'Tezonco': 1.545},
    'Tezonco': {'Periférico Oriente': 1.545, 'Olivos': 0.490},
    'Olivos': {'Tezonco': 0.490, 'Nopalera': 1.360},
    'Nopalera': {'Olivos': 1.360, 'Zapotitlán': 1.276},
    'Zapotitlán': {'Nopalera': 1.276, 'Tlaltenco': 1.115},
    'Tlaltenco': {'Zapotitlán': 1.115, 'Tláhuac': 1.298},
    'Tláhuac': {'Tlaltenco': 1.298}
}

# %%
class Node:
    def __init__(self, state, parent = None, action = None, path_cost = 0):
        self.state = state
        self.parent = parent
        self.action = action
        self.path_cost = path_cost

    def path(self):
        lista_path = []
        node = self
        while node:
            lista_path.append(node.state)
            node = node.parent
        return lista_path[::-1]

    def expand(self, problem):
        lista = []
        for action in problem.actions(self.state):
            lista.append(self.child_node(problem, action))
        return lista

    def child_node(self, problem, action):
        next_state = problem.result(self.state, action)
        step_cost = problem.action_cost(self.state, action, next_state)
        return Node(next_state, self, action, self.path_cost + step_cost)

# %%
def depth_first_graph_search(problem):
    start_node = Node(problem.initial)
    if problem.is_goal(start_node.state):
        return start_node
    frontier = [start_node]
    explored = set()

    while frontier:
        node = frontier.pop()
        explored.add(node.state)

        if problem.is_goal(node.state):
            return node

        for child in node.expand(problem):
            if child.state not in explored:
                frontier.append(child)
    return None

# %%
#Camino desde Cuatro caminos a Pantitlán con DFS
problem = GraphProblem("Cuatro Caminos", "Pantitlán", metro_cdmx)
node = depth_first_graph_search(problem)
print(node.path_cost)
node.path()
# Out:
# 33.878
# ['Cuatro Caminos',
#  'Panteones',
#  'Tacuba',
#  'San Joaquín',
#  'Polanco',
#  'Auditorio',
#  'Constituyentes',
#  'Tacubaya',
#  'San Pedro de los Pinos',
#  'San Antonio',
#  'Mixcoac',
#  'Insurgentes Sur',
#  'Hospital 20 de Noviembre',
#  'Zapata',
#  'Parque de los Venados',
#  'Eje Central',
#  'Ermita',
#  'Mexicaltzingo',
#  'Atlalilco',
#  'Escuadrón 201',
#  'Aculco',
#  'Apatlaco',
#  'Iztacalco',
#  'Coyuya',
#  'Santa Anita',
#  'La Viga',
#  'Chabacano',
#  'Jamaica',
#  'Mixiuhca',
#  'Velódromo',
#  'Ciudad Deportiva',
#  'Puebla',
#  'Pantitlán']

# %%
#Camino desde Politécnico a Taxqueña con DFS
problem = GraphProblem("Politécnico", "Tasqueña", metro_cdmx)
node = depth_first_graph_search(problem)
node.path()
# Out:
# ['Politécnico',
#  'Instituto del Petróleo',
#  'Lindavista',
#  'Deportivo 18 de Marzo',
#  'La Villa Basílica',
#  'Martín Carrera',
#  'Talismán',
#  'Bondojito',
#  'Consulado',
#  'Eduardo Molina',
#  'Aragón',
#  'Oceanía',
#  'Romero Rubio',
#  'Flores Magón',
#  'San Lázaro',
#  'Morelos',
#  'Tepito',
#  'Lagunilla',
#  'Garibaldi',
#  'Bellas Artes',
#  'San Juan de Letrán',
#  'Salto del Agua',
#  'Doctores',
#  'Obrera',
#  'Chabacano',
#  'Jamaica',
#  'Santa Anita',
#  'Coyuya',
#  'Iztacalco',
#  'Apatlaco',
#  'Aculco',
#  'Escuadrón 201',
#  'Atlalilco',
#  'Mexicaltzingo',
#  'Ermita',
#  'General Anaya',
#  'Tasqueña']

# %%
#Camino desde Zapata a Oceania con DFS
problem = GraphProblem("Zapata", "Oceanía", metro_cdmx)
node = depth_first_graph_search(problem)
node.path()
# Out:
# ['Zapata',
#  'Parque de los Venados',
#  'Eje Central',
#  'Ermita',
#  'Mexicaltzingo',
#  'Atlalilco',
#  'Escuadrón 201',
#  'Aculco',
#  'Apatlaco',
#  'Iztacalco',
#  'Coyuya',
#  'Santa Anita',
#  'La Viga',
#  'Chabacano',
#  'Jamaica',
#  'Mixiuhca',
#  'Velódromo',
#  'Ciudad Deportiva',
#  'Puebla',
#  'Pantitlán',
#  'Hangares',
#  'Terminal Aérea',
#  'Oceanía']

# %%
from collections import deque

def breadth_first_graph_search(problem):
    start_node = Node(problem.initial)
    if problem.is_goal(start_node.state):
        return start_node
    frontier = deque([start_node])
    explored = set()

    while frontier:
        node = frontier.popleft()
        explored.add(node.state)

        if problem.is_goal(node.state):
            return node

        for child in node.expand(problem):
            if child.state not in explored:
                frontier.append(child)
    return None

# %%
#Camino desde Cuatro caminos a Pantitlán con FS
problem = GraphProblem("Cuatro Caminos", "Pantitlán", metro_cdmx)
node = breadth_first_graph_search(problem)
node.path()
# Out:
# ['Cuatro Caminos',
#  'Panteones',
#  'Tacuba',
#  'San Joaquín',
#  'Polanco',
#  'Auditorio',
#  'Constituyentes',
#  'Tacubaya',
#  'Patriotismo',
#  'Chilpancingo',
#  'Centro Médico',
#  'Lázaro Cárdenas',
#  'Chabacano',
#  'Jamaica',
#  'Mixiuhca',
#  'Velódromo',
#  'Ciudad Deportiva',
#  'Puebla',
#  'Pantitlán']

# %%
#Camino desde Politécnico a Taxqueña con BFS
problem = GraphProblem("Politécnico", "Tasqueña", metro_cdmx)
node = breadth_first_graph_search(problem)
node.path()
# Out:
# ['Politécnico',
#  'Instituto del Petróleo',
#  'Autobuses del Norte',
#  'La Raza',
#  'Tlatelolco',
#  'Guerrero',
#  'Hidalgo',
#  'Bellas Artes',
#  'Allende',
#  'Zócalo',
#  'Pino Suárez',
#  'San Antonio Abad',
#  'Chabacano',
#  'Viaducto',
#  'Xola',
#  'Villa de Cortés',
#  'Nativitas',
#  'Portales',
#  'Ermita',
#  'General Anaya',
#  'Tasqueña']

# %%
#Camino desde Zapata a Oceania con BFS
problem = GraphProblem("Zapata", "Oceanía", metro_cdmx)
node = breadth_first_graph_search(problem)
node.path()
# Out:
# ['Zapata',
#  'División del Norte',
#  'Eugenia',
#  'Etiopía',
#  'Centro Médico',
#  'Lázaro Cárdenas',
#  'Chabacano',
#  'Jamaica',
#  'Fray Servando',
#  'Candelaria',
#  'San Lázaro',
#  'Flores Magón',
#  'Romero Rubio',
#  'Oceanía']
